# %% [markdown]
# # Module 3 Exercises - Data Manipulation

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load in the "dupedata.csv" file as a dataframe. Drop the duplicates from the dataframe, keeping the first value (save the resulting dataframe to a new variable).

# %%
import pandas as pd 
import numpy as np
location="datasets/dupedata.csv"
dupe_df=pd.read_csv(location)
dupe=dupe_df.drop_duplicates(keep='first')

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe in the previous exercise, select all the rows where students received a grade lower than 60 (they need a teacher conference on how to improve for the next test).

# %%
dupe_df.loc[dupe_df['grade']<60]
# Out:
#            fname       lname  gender  age  exercise  hours  grade  \
# 340        Abbot        Hall    male   16         4      3   58.9
# 410        Linda     Baldwin  female   16         5      2   59.0
# 556        Lacey      Nieves  female   18         1      2   57.9
# 664        Alika       Poole  female   19         2     16   32.0
# 672       Ciaran         Gay    male   19         4      3   59.3
# 972       Keegan   Rasmussen    male   19         4      3   43.0
# 1068      Isaiah  Harrington    male   17         1      4   58.9
# 1207       Selma       Stout  female   19         2      3   59.4
# 1237       Willa       Byers  female   14         2      4   59.2
# 1494       Jenna      Wagner  female   16         1      3   56.3
# 1876        Levi     Coleman    male   19         3      3   55.9
# 1888  Fitzgerald        Goff    male   18         1      4   59.8
# 1916        Gail      Mcneil  female   17         2      3   56.1
# 1930     Xanthus      Mcneil    male   16         3      4   59.8
#
#                                              address
# 340             84 Rock Creek Lane, Durham, NC 27703
# 410       970 SW. Second Ave., Cedar Falls, IA 50613
# 556   38 West Brickyard Avenue, Roslindale, MA 02131
# 664      9282 Purple Finch Lane, Lexington, NC 27292
# 672              157 Bridge Street, Corona, NY 11368
# 972    876 East Pilgrim Street, Chelmsford, MA 01824
# 1068         47 Mill Pond St., Haines City, FL 33844
# 1207                 5 Pierce St., Chester, PA 19013
# 1237           9466 Wayne Lane, Torrington, CT 06790
# 1494     8829 Shore Dr., Hopewell Junction, NY 12533
# 1876       9453 Laurel Street, Jersey City, NJ 07302
# 1888         3 West Shipley Rd., Langhorne, PA 19047
# 1916             8409A Spruce St., Fishers, IN 46037
# 1930       226 Redwood Lane, Boynton Beach, FL 33435

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe from Exercise 1, select all the rows where a student received a grade of 100 and change their grade to 103 (extra credit!).

# %%
dupe_df.loc[dupe_df['grade']==100, 'grade']=103

# %% [raw]
# sorteddf=dupe_df.sort_values('grade')

# %% [raw]
# sorteddf.tail()
# print(dupe_df.loc)

# %% [markdown]
# ### Exercise 4:
#
# Load in the "travel_times.csv" file as a dataframe. Drop the "Comments" column. Then remove rows from the dataframe that have missing values and assign the resulting dataframe as a new variable.

# %%
loca= "datasets/travel_times.csv"
df_travel= pd.read_csv(loca)
df_travel.head()
df_travel.drop('Comments', axis=1,inplace=True )
df_traveled= df_travel.dropna()
df_traveled.head()
# Out:
#           Date StartTime DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 6     1/2/2012     17:31    Monday    Home     51.37     123.2      82.9
# 7     1/2/2012     07:34    Monday     GSK     49.01     128.3      77.5
# 8   12/23/2011     08:01    Friday     GSK     52.91     130.3      80.9
# 9   12/22/2011     17:19  Thursday    Home     51.17     122.3      70.6
# 10  12/22/2011     08:16  Thursday     GSK     49.15     129.4      74.0
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All
# 6             87.3           -       37.2        35.3         No
# 7             85.9           -       37.9        34.3         No
# 8             88.3        8.89       39.3        36.0         No
# 9             78.1        8.89       43.5        39.3         No
# 10            81.4        8.89       39.8        36.2         No

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe from the exercise above (w/ no missing values), create bins that will categorize the AvgSpeed column as "slow" or "fast", and make a new column called "Speed" to hold those new values. Values less than 75 are "slow" and everything above is "fast".

# %%
df_traveled['AvgSpeed'].dtype
# Out:
# dtype('float64')

# %%
bins=[0, 75, 100]
categories= ['Slow', 'Fast']
df_traveled['Speed']=pd.cut(df_traveled['AvgSpeed'], bins, labels=categories)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_traveled.head()
# Out:
#           Date StartTime DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 6     1/2/2012     17:31    Monday    Home     51.37     123.2      82.9
# 7     1/2/2012     07:34    Monday     GSK     49.01     128.3      77.5
# 8   12/23/2011     08:01    Friday     GSK     52.91     130.3      80.9
# 9   12/22/2011     17:19  Thursday    Home     51.17     122.3      70.6
# 10  12/22/2011     08:16  Thursday     GSK     49.15     129.4      74.0
#
#     AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Speed
# 6             87.3           -       37.2        35.3         No  Fast
# 7             85.9           -       37.9        34.3         No  Fast
# 8             88.3        8.89       39.3        36.0         No  Fast
# 9             78.1        8.89       43.5        39.3         No  Slow
# 10            81.4        8.89       39.8        36.2         No  Slow

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a new column called "Police" which is equal to all the values being "no" (they were never stopped by police for speeding while traveling).

# %%
df_traveled['Police']='no'
df_traveled
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 6      1/2/2012     17:31     Monday    Home     51.37     123.2      82.9
# 7      1/2/2012     07:34     Monday     GSK     49.01     128.3      77.5
# 8    12/23/2011     08:01     Friday     GSK     52.91     130.3      80.9
# 9    12/22/2011     17:19   Thursday    Home     51.17     122.3      70.6
# 10   12/22/2011     08:16   Thursday     GSK     49.15     129.4      74.0
# 11   12/21/2011     07:45  Wednesday     GSK     51.77     124.8      71.7
# 12   12/20/2011     16:05    Tuesday    Home     51.45     130.1      75.2
# 13   12/20/2011     06:04    Tuesday     GSK     49.01     119.0      77.4
# 14   12/19/2011     16:18     Monday    Home     51.04     132.2      77.5
# 15   12/19/2011     07:34     Monday     GSK     52.00     137.8      76.5
# 16   12/16/2011     12:22     Friday    Home     51.05     128.4      86.9
# 17   12/16/2011     07:21     Friday     GSK     49.04     124.6      71.1
# 18   12/15/2011     16:14   Thursday    Home     51.06     126.9      80.5
# 19   12/15/2011     07:19   Thursday     GSK     51.68     123.5      68.1
# 20   12/14/2011     16:20  Wednesday    Home     51.04     123.4      75.1
# 21   12/14/2011     07:23  Wednesday     GSK     51.67     123.5      76.6
# 22   12/13/2011     17:43    Tuesday    Home     51.15     130.6      74.8
# 23   12/13/2011     07:25    Tuesday     GSK     49.19     126.1      65.4
# 24   12/12/2011     07:20     Monday     GSK     49.02     126.1      65.7
# 25    12/9/2011     12:04     Friday    Home     51.14     126.8      87.3
# 26    12/9/2011     07:22     Friday     GSK     51.69     128.4      74.0
# 27    12/8/2011     17:41   Thursday    Home     51.07     125.0      74.6
# 28    12/8/2011     07:14   Thursday     GSK     51.63     134.4      76.5
# 29    12/7/2011     16:12  Wednesday    Home     51.10     126.5      79.9
# 30    12/7/2011     07:18  Wednesday     GSK     51.64     124.6      73.6
# 31    12/6/2011     17:24    Tuesday    Home     51.25     123.5      77.3
# 32    12/6/2011     07:24    Tuesday     GSK     51.64     122.3      69.3
# 33    12/5/2011     16:18     Monday    Home     50.18     124.0      71.0
# 42   11/24/2011     16:15   Thursday    Home     51.49     126.6      74.0
# 43   11/24/2011     07:23   Thursday     GSK     51.69     124.9      73.3
# ..          ...       ...        ...     ...       ...       ...       ...
# 172    8/9/2011     08:15    Tuesday     GSK     49.08     134.8      60.5
# 173    8/8/2011     17:05     Monday    Home     52.35     127.5      76.9
# 174    8/8/2011     08:07     Monday     GSK     49.25     126.3      68.5
# 175    8/5/2011     17:00     Friday    Home     51.94     126.7      74.5
# 176    8/5/2011     08:20     Friday     GSK     49.13     123.9      74.1
# 177    8/4/2011     17:38   Thursday    Home     50.96     131.9      70.3
# 178    8/4/2011     08:17   Thursday     GSK     49.12     122.4      71.5
# 179    8/3/2011     17:14  Wednesday    Home     51.64     125.0      72.2
# 180    8/3/2011     08:06  Wednesday     GSK     49.06     121.9      71.5
# 181    8/2/2011     17:22    Tuesday    Home     51.16     124.2      76.3
# 182    8/2/2011     07:38    Tuesday     GSK     53.48     124.9      68.8
# 183   7/29/2011     20:31     Friday    Home     50.68     135.6     107.7
# 184   7/29/2011     08:22     Friday     GSK     49.07     121.1      73.2
# 185   7/28/2011     17:46   Thursday    Home     51.09     128.5      76.0
# 186   7/28/2011     08:11   Thursday     GSK     49.11     120.1      69.1
# 187   7/27/2011     17:24  Wednesday    Home     50.98     124.9      68.3
# 188   7/27/2011     08:15  Wednesday     GSK     48.82     124.5      70.4
# 189   7/26/2011     17:15    Tuesday    Home     51.28     122.1      43.7
# 190   7/26/2011     08:11    Tuesday     GSK     49.16     122.6      71.9
# 191   7/25/2011     16:59     Monday    Home     51.05     126.6      70.4
# 192   7/25/2011     08:06     Monday     GSK     48.32     121.2      63.4
# 193   7/22/2011     16:47     Friday    Home     51.24     126.3      75.8
# 194   7/22/2011     08:28     Friday     GSK     51.05     123.3      88.9
# 195   7/21/2011     07:59   Thursday     GSK     48.35     129.3      81.5
# 196   7/20/2011     17:17  Wednesday    Home     53.47     124.0      58.6
# 197   7/20/2011     08:24  Wednesday     GSK     48.50     125.8      75.7
# 198   7/19/2011     17:17    Tuesday    Home     51.16     126.7      92.2
# 199   7/19/2011     08:11    Tuesday     GSK     50.96     124.3      82.3
# 200   7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201   7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Speed Police
# 6              87.3           -       37.2        35.3         No  Fast     no
# 7              85.9           -       37.9        34.3         No  Fast     no
# 8              88.3        8.89       39.3        36.0         No  Fast     no
# 9              78.1        8.89       43.5        39.3         No  Slow     no
# 10             81.4        8.89       39.8        36.2         No  Slow     no
# 11             78.9        8.89       43.3        39.4         No  Slow     no
# 12             82.7        8.89       41.1        37.3         No  Fast     no
# 13             82.0        8.89       38.0        35.9         No  Fast     no
# 14             83.5        8.89       39.5        36.7         No  Fast     no
# 15             87.8        8.89       40.8        35.5         No  Fast     no
# 16             90.6        9.08       35.2        33.8         No  Fast     no
# 17             80.2        9.08       41.4        36.7         No  Slow     no
# 18             84.9        9.08       38.1        36.1         No  Fast     no
# 19             75.8        9.08       45.6        40.9         No  Slow     no
# 20             79.4        9.08       40.8        38.6         No  Fast     no
# 21             82.7        9.08       40.5        37.5         No  Fast     no
# 22             82.4        9.08       41.0        37.2         No  Slow     no
# 23             74.2        9.08       45.1        39.8         No  Slow     no
# 24             74.0        9.76       44.8        39.7         No  Slow     no
# 25             90.2        9.76       35.2        34.0         No  Fast     no
# 26             77.3        9.76       41.9        40.1         No  Slow     no
# 27             81.5        9.76       41.1        37.6         No  Slow     no
# 28             84.3        9.76       40.5        36.7         No  Fast     no
# 29             85.6        9.76       38.4        35.8         No  Fast     no
# 30             82.0        9.76       42.1        37.8         No  Slow     no
# 31             81.9        9.16       39.8        37.6         No  Fast     no
# 32             74.7        9.16       44.7        41.5         No  Slow     no
# 33             79.5        9.16       42.4        37.9         No  Slow     no
# 42             82.8         9.3       41.8        37.3         No  Slow     no
# 43             80.3         9.3       42.3        38.6         No  Slow     no
# ..              ...         ...        ...         ...        ...   ...    ...
# 172            67.2        8.54       48.7        43.8         No  Slow     no
# 173            84.2        8.54       40.9        37.3         No  Fast     no
# 174            78.2        8.54       43.1        37.8         No  Slow     no
# 175            82.6        8.48       41.9        37.7         No  Slow     no
# 176            79.9        8.48       39.8        36.9         No  Slow     no
# 177            78.5        8.48       43.5        38.9         No  Slow     no
# 178            77.3        8.48       41.2        38.2         No  Slow     no
# 179            78.7        8.48       42.9        39.4         No  Slow     no
# 180            78.7        8.48       41.2        37.4         No  Slow     no
# 181            83.2        8.48       40.2        36.9         No  Fast     no
# 182            78.8        8.48       46.7        40.7         No  Slow     no
# 183           110.4        8.45       28.2        27.6        Yes   NaN     no
# 184            77.7        8.45       40.2        37.9         No  Slow     no
# 185            84.8        8.45       40.3        36.2         No  Fast     no
# 186            73.1        8.45       42.6        40.3         No  Slow     no
# 187            71.9        8.45       44.8        42.6         No  Slow     no
# 188            77.8        8.45       41.6        37.6         No  Slow     no
# 189            51.5        8.45       70.5        59.8         No  Slow     no
# 190            76.8        8.45       41.0        38.4         No  Slow     no
# 191            78.8        8.45       51.1        38.9         No  Slow     no
# 192            78.4        8.45       45.7        37.0         No  Slow     no
# 193            81.8        8.28       40.6        37.6         No  Fast     no
# 194            96.7        8.28       34.5        31.7        Yes  Fast     no
# 195            89.0        8.28       35.6        32.6        Yes  Fast     no
# 196            71.0        7.89       54.8        45.2         No  Slow     no
# 197            87.3        7.89       38.5        33.3        Yes  Fast     no
# 198           102.6        7.89       33.3        29.9        Yes  Fast     no
# 199            96.4        7.89       37.2        31.7        Yes  Fast     no
# 200            82.4        7.89       65.5        39.7         No  Slow     no
# 201            95.1        7.89       40.1        32.1        Yes  Fast     no
#
# [188 rows x 14 columns]

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe from the previous exercise, pick a method (Standard Deviation or Interquartile Range) and remove the outliers from the "FuelEconomy" column.

# %%
df_tf=df_traveled.dropna

# %%
#data= df_traveled.set_index('FuelEconomy')
#df_tf['FuelEconomy'].dtypes== '0'
df_tf.loc[df_tf['FuelEconomy']=='-', ['FuelEconomy']]=0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e76267c57067> in <module>()
#       1 #data= df_traveled.set_index('FuelEconomy')
#       2 #df_tf['FuelEconomy'].dtypes== '0'
# ----> 3 df_tf.loc[df_tf['FuelEconomy']=='-', ['FuelEconomy']]=0
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
df_tff=df_tf['FuelEconomy'].astype(float)
df_tff.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6725805dc554> in <module>()
# ----> 1 df_tff=df_tf['FuelEconomy'].astype(float)
#       2 df_tff.head()
#
# TypeError: 'method' object is not subscriptable

# %%
df_tff['FuelEconomy'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b2de06dc7a59> in <module>()
# ----> 1 df_tff['FuelEconomy'].unique()
#
# NameError: name 'df_tff' is not defined

# %%
q1= df_traveled['FuelEconomy'].quantile(.25)
q3= df_traveled['FuelEconomy'].quantile(.75)
iqr= q3 - q1
toprange= q3 + iqr *1.5
botrange=q1 -iqr *1.5
newdf= df_traveled.copy()
newdf
